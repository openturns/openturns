# %% [markdown]
# # Calibration of the Chaboche model with non linear least squares

# %% [markdown]
# The goal of this example is to calibrate the simulator associated with the Chaboche model with non linear least squares.

# %%
import openturns as ot
import numpy as np
import PostCalibrationResult as pcr

# %% [markdown]
# ## Read the observations

# %% [markdown]
# We begin by reading the observations from the data file. There are 100 observations of the couple (strain,stress).

# %%
observedSample = ot.Sample_ImportFromCSVFile("calibration_chaboche_observations.csv")
nbobs = observedSample.getSize()
strainobs = observedSample[:,0]
stressobs = observedSample[:,1]
nbobs
# Out:
# 100

# %%
strainobs.setDescription(["Strain"])

# %% [markdown]
# ## Define the model

# %% [markdown]
# We define the model which has 4 inputs and one output `stress`.

# %%
def modelChaboche(X):
    strain,R,C,gamma = X
    # Workaround for https://github.com/openturns/openturns/issues/1092
    R = R*1.e6
    C = C*1.e6
    stress = R + C*(1-np.exp(-gamma*strain))
    return [stress]

# %%
modelFunc = ot.PythonFunction(4, 1, modelChaboche)
modelFunc.setDescription(["strain", "R", "C", "gamma", "stress"])

# %% [markdown]
# Define the value of the reference values of the $\theta$ parameter. In the bayesian framework, this is called the mean of the *prior* gaussian distribution. In the data assimilation framework, this is called the *background*.

# %%
R = 700 # Exact : 750e6
C = 2500 # Exact : 2750e6
Gamma = 8. # Exact : 10
thetaPrior = ot.Point([R,C,Gamma])
thetaPrior.setDescription(("R","C","Gamma"))

# %% [markdown]
# The following statement create the calibrated function from the model. The calibrated parameters Ks, Zv, Zm are at indices 1, 2, 3 in the inputs arguments of the model.

# %%
calibratedIndices = [1,2,3]
mycf = ot.ParametricFunction(modelFunc, calibratedIndices, thetaPrior)

# %% [markdown]
# ## Calibration

# %% [markdown]
# Defined the covariance matrix of the parameters $\theta$ to calibrate.

# %% [markdown]
# The `NonLinearLeastSquaresCalibration` class performs the non linear least squares calibration by minimizing the squared euclidian norm between the predictions and the observations.

# %%
algo = ot.NonLinearLeastSquaresCalibration(mycf, strainobs, stressobs, thetaPrior)

# %% [markdown]
# The `run` method computes the solution of the problem.

# %%
algo.run()

# %%
calibrationResult = algo.getResult()

# %% [markdown]
# ## Analysis of the results

# %% [markdown]
# The `getParameterMAP` method returns the maximum of the posterior distribution of $\theta$.

# %%
thetaMAP = calibrationResult.getParameterMAP()
thetaMAP
# Out:
# class=Point name=Unnamed dimension=3 values=[746.708,2818.99,9.66604]

# %% [markdown]
# We can compute a 95% confidence interval of the parameter $\theta^\star$.

# %%
thetaPosterior = calibrationResult.getParameterPosterior()
thetaPosterior.computeBilateralConfidenceIntervalWithMarginalProbability(0.95)[0]
# Out:
# class=Interval name=Unnamed dimension=3 lower bound=class=Point name=Unnamed dimension=3 values=[711.166,2297.18,7.27052] upper bound=class=Point name=Unnamed dimension=3 values=[781.525,3428.65,12.9351] finite lower bound=[1,1,1] finite upper bound=[1,1,1]

# %% [markdown]
# We can see that all three parameters are estimated with a large confidence interval.

# %%
mypcr = pcr.PostCalibrationResult(calibrationResult,mycf, strainobs, stressobs)

# %%
graph = mypcr.drawModelVsObservations()
graph.setLegendPosition("topleft")
graph
# Out:
# class=Graph name=Unnamed implementation=class=GraphImplementation name=Unnamed title= xTitle=Strain yTitle=Stress axes=ON grid=ON legendposition=topleft legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=