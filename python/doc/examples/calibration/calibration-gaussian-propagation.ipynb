# %% [markdown]
# # Calibration on the flooding model - propagation of the prior
#
# Dans ce texte, nous réalisons la propagation des incertitudes sur un modèle de hauteurs d'eau. L'objectif de cette propagation est de vérifier que la loi à priori que l'on peut poser sur les paramètres est compatible avec les observations.

# %% [markdown]
# ### Objectifs
# * Prédire la hauteur de l'eau H en fonction du débit Q
#
# ### Entrées
# On considère les quatre variables suivantes :
# * Q : le débit de la rivière ($m^3/s$)
# * Ks : le coefficient de Strickler ($m^{1/3}/s$)
# * Zv : la côte du fond de la rivière en aval (m)
# * Zm : la côte du fond de la rivière en amont (m)
#
# ### Notes :
# * Quand Ks augmente, le fond de la rivière oppose moins de frottement à l'écoulement de l'eau.
# * On fait l'hypothèse que les variables sont statistiquement indépendantes.
#
# ### Paramètres
#
# On considère les valeurs suivantes des paramètres :
# * la longueur du tronçon de rivière L = 5000 (m),
# * la largeur de la rivière B = 300 (m).
#
# ### Sortie
#
# La pente de la rivière est supposée proche de zéro, ce qui implique :
# $$
# \alpha = \frac{Z_m - Z_v}{L},
# $$
# si $Z_m \geq Z_v$.
# La hauteur de l'eau est modélisée par :
# $$
# H = \left(\frac{Q}{K_s B \sqrt{\alpha}}\right)^{0.6},
# $$
# pour tous $K_s, Q>0$.
#
# <img src="river_section_adjusted_light.png" width="400" />
#
# ### Lois de distribution
#
# On fait l'hypothèse que le débit suit la loi de Gumbel tronquée suivante :
#
# |Variable|Distribution|
# | ------------- |-------------|
# |Q|Gumbel(scale=558, mode=1013)>0|
#
# ### Paramètres à identifier
#
# Les variables $(Kz,Zv,Zm)$ à caler sont les suivantes :
# $$
# Ks = 30, \qquad Zv = 50, \qquad Zm = 55.
# $$
#
# ### Observations
#
# Les hauteurs d'eau observées sont entachées d'un bruit d'observation de moyenne nulle et d'écart-type
# $$
# \sigma=0.1.
# $$
# Les hauteurs d'eau observées sont
# $$
# H_i = G(Q_i,Ks,Zv,Zm) + \epsilon
# $$
# pour $i=1,...,n$ où
# $$
# \epsilon \sim \mathcal{N}(0,\sigma^2).
# $$
# On considère un échantillon de taille
# $$
# n=100.
# $$
# Les observations sont des couples $(Q,H)$.
#
# ### Analyse
#
# Dans ce modèle, les variables $Z_m$ et $Z_v$ ne sont pas identifiables, puisque seule la différence $Z_m-Z_v$ importe.

# %%
import pylab as pl
import openturns as ot
from math import sqrt

# %% [markdown]
# ## Définition du modèle

# %% [markdown]
# On commence par charger les données : il y a 100 observations du couple (Q,H).

# %%
observedSample = ot.Sample_ImportFromCSVFile("calage-KS-observations.csv")
nbobs = observedSample.getSize()
Qobs = observedSample[:,0]
Hobs = observedSample[:,1]
nbobs
# Out:
# 100

# %%
Hobs.setDescription(["Hauteur (m)"])

# %%
graph = ot.VisualTest_DrawHistogram(Hobs)
graph.setXTitle("Hauteur (m)")
graph.setTitle("n=%s" % (nbobs))
graph.setLegends([""])
graph
# Out:
# class=Graph name=sample histogram implementation=class=GraphImplementation name=sample histogram title=n=100 xTitle=Hauteur (m) yTitle=frequency axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=44 dimension=2 data=[[0.310763,0],[0.538627,0],[0.538627,0],[0.538627,0.0438858],[0.994356,0.0438858],[0.994356,0],[0.994356,0],[0.994356,0.131657],[1.45008,0.131657],[1.45008,0],[1.45008,0],[1.45008,0.482744],[1.90581,0.482744],[1.90581,0],[1.90581,0],[1.90581,0.504687],[2.36154,0.504687],[2.36154,0],[2.36154,0],[2.36154,0.504687],[2.81727,0.504687],[2.81727,0],[2.81727,0],[2.81727,0.285258],[3.273,0.285258],[3.273,0],[3.273,0],[3.273,0.1536],[3.72873,0.1536],[3.72873,0],[3.72873,0],[3.72873,0.0658287],[4.18445,0.0658287],[4.18445,0],[4.18445,0],[4.18445,0],[4.64018,0],[4.64018,0],[4.64018,0],[4.64018,0.0219429],[5.09591,0.0219429],[5.09591,0],[5.09591,0],[5.32377,0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]

# %% [markdown]
# Puis on définit la fonction crue, qui possède 4 entrées Q, Ks, Zv, Zm et une sortie H.

# %%
def functionCrueModel(X):
    Q, K_s, Z_v, Z_m = X
    L = 5.0e3
    B = 300.0
    alpha = (Z_m - Z_v)/L
    H = (Q/(K_s*B*sqrt(alpha)))**(3.0/5.0)
    return [H]

# %%
modelPyFunc = ot.PythonFunction(4, 1, functionCrueModel)
modelPyFunc.setDescription(["Q", "Ks", "Zv", "Zm","H"])

# %% [markdown]
# Les lignes suivantes créent la fonction de calage à partir de la fonction modèle :
# * les entrées X sont à l'indice 0,
# * les variables de calage sont aux indices 1, 2, 3,
# * les observations sont données dans `Qobs`.

# %%
KsInitial = 25.
ZvInitial = 47.
ZmInitial = 53.
thetaB = ot.Point([KsInitial,ZvInitial,ZmInitial])

# %%
calibratedIndices = [1,2,3]
mycf = ot.ParametricFunction(modelPyFunc, calibratedIndices, thetaB)
mycf(Qobs[0])
# Out:
# class=Point name=Unnamed dimension=1 values=[2.25519]

# %% [markdown]
# ## Propagation des lois à priori

# %% [markdown]
# Une condition de compatibilité est requise entre Zv et Zm. Sinon, il se peut que $Z_v\geq Z_m$, ce qui n'est pas compatible avec le modèle.
# * Soit le vecteur moyen est tel que, compte tenu de la variance de chaque variable, la probabilité que $Z_v\geq Z_m$ est très faible.
# * Soit une dépendance entre $Z_v$ et $Z_m$ implique que la probabilité que $Z_v\geq Z_m$ est très faible.

# %%
# Ecart-type des paramètres
sigmaKs = 7.
sigmaZv = 1.
sigmaZm = 1.
sigmaTheta = [sigmaKs,sigmaZv,sigmaZm]

# %%
Sigma = ot.CovarianceMatrix(3)
Sigma[0,0] = sigmaKs
Sigma[1,1] = sigmaZv
Sigma[2,2] = sigmaZm
Sigma
# Out:
# class=CovarianceMatrix dimension=3 implementation=class=MatrixImplementation name=Unnamed rows=3 columns=3 values=[7,0,0,0,1,0,0,0,1]

# %%
prior = ot.Normal(thetaB,Sigma)

# %%
n = 100

# %%
theta = prior.getSample(n)

# %%
Hpredicted = ot.Sample(nbobs,n)
for i in range(nbobs):
    for j in range(n):
        mycf.setParameter(theta[j])
        Hpredicted[i,j] = mycf(Qobs[i])[0]

# %%
graph = ot.Graph("","Q (m3/s)","H (m)",True)
# Predictions
for i in range(nbobs):
    Qobs_i = ot.Point(n)
    for j in range(n):
        Qobs_i[j] = Qobs[i,0]
    cloud = ot.Cloud(Qobs_i,Hpredicted[i,:])
    graph.add(cloud)
# Observations
cloud = ot.Cloud(Qobs,Hobs)
cloud.setColor("red")
graph.add(cloud)
graph
# Out:
# class=Graph name=Unnamed implementation=class=GraphImplementation name=Unnamed title= xTitle=Q (m3/s) yTitle=H (m) axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[1007.61,2.08972],[1007.61,1.88815],[1007.61,2.38524],[1007.61,2.07583],[1007.61,2.66768],[1007.61,2.41561],[1007.61,2.35396],[1007.61,2.17416],[1007.61,2.1403],[1007.61,2.12863],[1007.61,2.58657],[1007.61,2.24123],[1007.61,2.09612],[1007.61,2.32291],[1007.61,2.20639],[1007.61,1.81164],[1007.61,2.25615],[1007.61,2.62063],[1007.61,2.05098],[1007.61,2.47629],[1007.61,1.97977],[1007.61,2.16379],[1007.61,2.07112],[1007.61,2.09437],[1007.61,2.23667],[1007.61,2.75835],[1007.61,2.37081],[1007.61,2.38513],[1007.61,2.42179],[1007.61,2.26309],[1007.61,2.25161],[1007.61,2.0708],[1007.61,2.20627],[1007.61,2.36959],[1007.61,1.96105],[1007.61,2.73329],[1007.61,2.31076],[1007.61,2.24257],[1007.61,2.5882],[1007.61,2.48093],[1007.61,2.89823],[1007.61,2.48766],[1007.61,1.89313],[1007.61,2.31072],[1007.61,2.62052],[1007.61,2.46831],[1007.61,2.02955],[1007.61,2.27499],[1007.61,2.41297],[1007.61,2.08406],[1007.61,2.24367],[1007.61,2.2878],[1007.61,2.32103],[1007.61,2.22628],[1007.61,2.14321],[1007.61,2.53743],[1007.61,2.25712],[1007.61,2.27248],[1007.61,2.13423],[1007.61,2.15483],[1007.61,2.3094],[1007.61,2.26694],[1007.61,2.357],[1007.61,2.56414],[1007.61,2.4201],[1007.61,2.42821],[1007.61,2.03922],[1007.61,2.19123],[1007.61,2.21469],[1007.61,2.31652],[1007.61,2.15928],[1007.61,2.10721],[1007.61,2.43715],[1007.61,2.59319],[1007.61,2.24024],[1007.61,2.15474],[1007.61,2.31205],[1007.61,2.25119],[1007.61,2.15433],[1007.61,2.07274],[1007.61,2.39928],[1007.61,2.49201],[1007.61,2.23632],[1007.61,2.233],[1007.61,1.95484],[1007.61,2.10246],[1007.61,3.10165],[1007.61,2.20681],[1007.61,2.48049],[1007.61,2.32725],[1007.61,2.37931],[1007.61,2.16361],[1007.61,2.38617],[1007.61,1.98069],[1007.61,2.05525],[1007.61,2.17912],[1007.61,2.59037],[1007.61,2.42231],[1007.61,2.76028],[1007.61,2.34968]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1,class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=100 dimension=2 data=[[1620.01,2.77859],[1620.01,2.51056],[1620.01,3.17153],[1620.01,2.76012],[1620.01,3.54707],[1620.01,3.21191],[1620.01,3.12993],[1620.01,2.89087],[1620.01,2.84584],[1620.01,2.83032],[1620.01,3.43922],[1620.01,2.98004],[1620.01,2.7871],[1620.01,3.08865],[1620.01,2.93371],[1620.01,2.40884],[1620.01,2.99988],[1620.01,3.48451],[1620.01,2.72708],[1620.01,3.29259],[1620.01,2.63239],[1620.01,2.87707],[1620.01,2.75386],[1620.01,2.78477],[1620.01,2.97398],[1620.01,3.66763],[1620.01,3.15234],[1620.01,3.17138],[1620.01,3.22012],[1620.01,3.0091],[1620.01,2.99384],[1620.01,2.75343],[1620.01,2.93355],[1620.01,3.15071],[1620.01,2.6075],[1620.01,3.6343],[1620.01,3.07249],[1620.01,2.98183],[1620.01,3.44139],[1620.01,3.29876],[1620.01,3.85361],[1620.01,3.3077],[1620.01,2.51719],[1620.01,3.07244],[1620.01,3.48436],[1620.01,3.28197],[1620.01,2.69858],[1620.01,3.02493],[1620.01,3.20839],[1620.01,2.77106],[1620.01,2.98329],[1620.01,3.04197],[1620.01,3.08615],[1620.01,2.96017],[1620.01,2.84971],[1620.01,3.37389],[1620.01,3.00117],[1620.01,3.02159],[1620.01,2.83776],[1620.01,2.86516],[1620.01,3.07069],[1620.01,3.01422],[1620.01,3.13398],[1620.01,3.4094],[1620.01,3.21788],[1620.01,3.22866],[1620.01,2.71145],[1620.01,2.91356],[1620.01,2.94475],[1620.01,3.08016],[1620.01,2.87107],[1620.01,2.80185],[1620.01,3.24054],[1620.01,3.44802],[1620.01,2.97872],[1620.01,2.86504],[1620.01,3.0742],[1620.01,2.99329],[1620.01,2.86449],[1620.01,2.75601],[1620.01,3.19019],[1620.01,3.3135],[1620.0 ...

# %% [markdown]
# Since the predictions (in blue) are well within the observations (in red), the model can be calibrated.
