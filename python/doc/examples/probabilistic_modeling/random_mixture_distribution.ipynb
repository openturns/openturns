# %% [markdown]
# # Create a random mixture of distributions

# %% [markdown]
# In this example we are going to build an affine combination of input random variables.
#
# $$ Y = 2 + 5 X_1 + X_2 $$
#
# where:
#
# - $X1 \sim \mathcal{E}(\lambda=1.5)$
# - $X2 \sim \mathcal{N}(\mu=4, \sigma=1)$
#
# This notion is different from the Mixture where the combination is made on the probability density functions and not on the univariate random variable.

# %%
from __future__ import print_function
import openturns as ot

# %%
# create the distributions associated to the input random variables
X1 = ot.Exponential(1.5)
X2 = ot.Normal(4.0, 1.0)

# %%
# offset
a0 = 2.0

# %%
# Create the weights
weight = [5.0, 1.0]

# %%
# create the affine combination
distribution = ot.RandomMixture([X1, X2], weight, a0)
distribution
# Out:
# class=RandomMixture name=RandomMixture distribution collection=[class=Normal name=Normal dimension=1 mean=class=Point name=Unnamed dimension=1 values=[6] sigma=class=Point name=Unnamed dimension=1 values=[1] correlationMatrix=class=CorrelationMatrix dimension=1 implementation=class=MatrixImplementation name=Unnamed rows=1 columns=1 values=[1],class=Exponential name=Exponential dimension=1 lambda=0.3 gamma=0] weights =class=Matrix implementation=class=MatrixImplementation name=Unnamed rows=1 columns=2 values=[1,1] constant=class=Point name=Unnamed dimension=1 values=[0]

# %%
# ask its mean
distribution.getMean()
# Out:
# class=Point name=Unnamed dimension=1 values=[9.33333]

# %%
# ask its variance
distribution.getCovariance()[0, 0]
# Out:
# 12.11111111111111

# %%
# ask the 90% quantile
distribution.computeQuantile(0.9)
# Out:
# class=Point name=Unnamed dimension=1 values=[13.8253]

# %%
# ask its probability to exceeds 3
distribution.computeSurvivalFunction(3.0)
# Out:
# 0.9998938618593294

# %%
# draw PDF
distribution.drawPDF()
# Out:
# class=Graph name=X0 PDF implementation=class=GraphImplementation name=X0 PDF title=X0 PDF xTitle=X0 yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=X0 PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[-1.56675,2.70952e-15],[-1.39506,1.77244e-14],[-1.22337,7.0597e-14],[-1.05168,2.52297e-13],[-0.879988,8.59411e-13],[-0.708297,2.82979e-12],[-0.536607,9.03964e-12],[-0.364916,2.8043e-11],[-0.193225,8.45087e-11],[-0.0215347,2.47418e-10],[0.150156,7.03774e-10],[0.321847,1.94503e-09],[0.493537,5.22309e-09],[0.665228,1.36286e-08],[0.836919,3.45553e-08],[1.00861,8.51407e-08],[1.1803,2.03863e-07],[1.35199,4.74396e-07],[1.52368,1.07292e-06],[1.69537,2.35854e-06],[1.86706,5.03959e-06],[2.03875,1.04678e-05],[2.21044,2.11376e-05],[2.38214,4.14983e-05],[2.55383,7.92175e-05],[2.72552,0.000147052],[2.89721,0.000265475],[3.0689,0.00046616],[3.24059,0.000796272],[3.41228,0.00132332],[3.58397,0.00214003],[3.75566,0.00336821],[3.92735,0.00516052],[4.09904,0.00769836],[4.27073,0.0111846],[4.44242,0.0158302],[4