# %% [markdown]
# # Create a gaussian process from a cov. model using HMatrix
#
# In this basic example we are going to build a gaussian process from its covariance model and using the `HMatrix` as sampling method.

# %%
from __future__ import print_function
import openturns as ot

# %% [markdown]
# Define the covariance model :

# %%
dimension = 1
amplitude = [1.0] * dimension
scale = [10] * dimension
covarianceModel = ot.AbsoluteExponential(scale, amplitude)

# %% [markdown]
# Define the time grid on which we want to sample the gaussian process :

# %%
# define a mesh
tmin = 0.0
step = 0.01
n = 10001
timeGrid = ot.RegularGrid(tmin, step, n)

# %% [markdown]
# Finally define the gaussian process :

# %%
# create the process
process = ot.GaussianProcess(covarianceModel, timeGrid)
print(process)
# Out:
# GaussianProcess(trend=[x0]->[0.0], covariance=AbsoluteExponential(scale=[10], amplitude=[1]))

# %% [markdown]
# We set the sampling method to `HMAT`

# %%
process.setSamplingMethod(1)

# %% [markdown]
# We sample the process :

# %%
# draw a sample
sample = process.getSample(6)
sample.drawMarginal(0)
# Out:
# class=Graph name=Unnamed - 0 marginal implementation=class=GraphImplementation name=Unnamed - 0 marginal title=Unnamed - 0 marginal xTitle=Time yTitle=Values axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10001 dimension=2 data=[[0,0.712034],[0.01,-0.495869],[0.02,-0.229322],...,[99.98,0.146075],[99.99,0.407385],[100,0.837986]] color=#ff0000 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10001 dimension=2 data=[[0,-0.870758],[0.01,1.03275],[0.02,1.58306],...,[99.98,1.42257],[99.99,0.795186],[100,0.890725]] color=#ffdb00 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10001 dimension=2 data=[[0,-0.472327],[0.01,-0.547419],[0.02,-0.469521],...,[99.98,0.35615],[99.99,0.763997],[100,0.0865822]] color=#49ff00 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10001 dimension=2 data=[[0,-1.40169],[0.01,-1.48813],[0.02,-2.48503],...,[99.98,-0.322679],[99.99,-1.52117],[100,-0.608028]] color=#00ff92 fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10001 dimension=2 data=[[0,0.892413],[0.01,-0.0511719],[0.02,0.901085],...,[99.98,-0.505829],[99.99,-0.862572],[100,-0.870607]] color=#0092ff fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1,class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=10001 dimension=2 data=[[0,2.64555],[0.01,2.95159],[0.02,1.93935],...,[99.98,-1.00253],[99.99,-0.891258],[100,-2.02833]] color=#4900ff fillStyle=solid lineStyle=solid pointStyle=none lineWidth=1]

# %% [markdown]
# We notice here that we are able to sample the covariance model over a mesh of size `10000`, which is usually tricky on laptop. This is mainly due to the compression.
