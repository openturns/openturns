# %% [markdown]
# # Create a Bayes distribution

# %% [markdown]
# In this basic example we are going to build the distribution of the random vector
#
# $$( \underline{X}|\underline{\Theta}, \underline{Y})$$
#
# with X conditioned by the random variable Theta obtained with the random variable Y through a function f
#
# $$\underline{\Theta}=f(\underline{Y})$$

# %%
from __future__ import print_function
import openturns as ot

# %%
# create the Y distribution
YDist = ot.Uniform(-1.0, 1.0)

# %%
# create Theta=f(y)
f = ot.SymbolicFunction(['y'], ['y', '1 + y'])

# %%
# create the X|Theta distribution
XgivenThetaDist = ot.Uniform()

# %%
# create the distribution
XDist = ot.BayesDistribution(XgivenThetaDist, YDist, f)
XDist.setDescription(['X|Theta=f(y)', 'y'])
XDist
# Out:
# class=BayesDistribution name=BayesDistribution dimension=2 conditioned distribution=class=Uniform name=Uniform dimension=1 a=-1 b=1 conditioning distribution=class=Uniform name=Uniform dimension=1 a=-1 b=1 link function=class=Function name=Unnamed implementation=class=FunctionImplementation name=Unnamed description=[y,y0,y1] evaluationImplementation=class=SymbolicEvaluation name=Unnamed inputVariablesNames=[y] outputVariablesNames=[y0,y1] formulas=[y,1 + y] gradientImplementation=class=SymbolicGradient name=Unnamed evaluation=class=SymbolicEvaluation name=Unnamed inputVariablesNames=[y] outputVariablesNames=[y0,y1] formulas=[y,1 + y] hessianImplementation=class=SymbolicHessian name=Unnamed evaluation=class=SymbolicEvaluation name=Unnamed inputVariablesNames=[y] outputVariablesNames=[y0,y1] formulas=[y,1 + y]

# %%
# Get a sample
XDist.getSample(5)
# Out:
# class=Sample name=BayesDistribution implementation=class=SampleImplementation name=BayesDistribution size=5 dimension=2 description=[X|Theta=f(y),y] data=[[1.14256,0.259753],[-0.696945,-0.729447],[0.663537,-0.305886],[1.3444,0.841359],[-0.580831,-0.873588]]

# %%
# draw PDF
XDist.drawPDF()
# Out:
# class=Graph name=[X|Theta=f(y),y] iso-PDF implementation=class=GraphImplementation name=[X|Theta=f(y),y] iso-PDF title=[X|Theta=f(y),y] iso-PDF xTitle=X|Theta=f(y) yTitle=y axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=[X|Theta=f(y),y] iso-PDF implementation=class=Contour name=[X|Theta=f(y),y] iso-PDF x=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=1 data=[[-0.999956],[-0.976519],[-0.953082],[-0.929646],[-0.906209],[-0.882772],[-0.859335],[-0.835898],[-0.812462],[-0.789025],[-0.765588],[-0.742151],[-0.718714],[-0.695277],[-0.671841],[-0.648404],[-0.624967],[-0.60153],[-0.578093],[-0.554657],[-0.53122],[-0.507783],[-0.484346],[-0.460909],[-0.437473],[-0.414036],[-0.390599],[-0.367162],[-0.343725],[-0.320288],[-0.296852],[-0.273415],[-0.249978],[-0.226541],[-0.203104],[-0.179668],[-0.156231],[-0.132794],[-0.109357],[-0.0859203],[-0.0624835],[-0.0390467],[-0.0156099],[0.00782692],[0.0312637],[0.0547005],[0.0781374],[0.101574],[0.125011],[0.148448],[0.171885],[0.195321],[0.218758],