# %% [markdown]
# # Create a conditional distribution

# %% [markdown]
# In this basic example we are going to build the distribution of the random vector X conditioned by the random variable Theta
#
# $$ \underline{X}|\underline{\Theta}$$
#
# with Theta obtained with the random variable Y through a function f
#
# $$\underline{\Theta}=f(\underline{Y})$$

# %%
from __future__ import print_function
import openturns as ot

# %%
# create the Y distribution
YDist = ot.Uniform(-1.0, 1.0)

# %%
# create Theta=f(y)
f = ot.SymbolicFunction(['y'], ['y', '1+y^2'])

# %%
# create the X|Theta distribution
XgivenThetaDist = ot.Uniform()

# %%
# create the distribution
XDist = ot.ConditionalDistribution(XgivenThetaDist, YDist, f)
XDist.setDescription(['X|Theta=f(y)'])
XDist
# Out:
# class=ConditionalDistribution name=ConditionalDistribution dimension=1 conditioned distribution=class=Uniform name=Uniform dimension=1 a=-1 b=1 conditioning distribution=class=Uniform name=Uniform dimension=1 a=-1 b=1 link function=class=Function name=Unnamed implementation=class=FunctionImplementation name=Unnamed description=[y,y0,y1] evaluationImplementation=class=SymbolicEvaluation name=Unnamed inputVariablesNames=[y] outputVariablesNames=[y0,y1] formulas=[y,1+y^2] gradientImplementation=class=SymbolicGradient name=Unnamed evaluation=class=SymbolicEvaluation name=Unnamed inputVariablesNames=[y] outputVariablesNames=[y0,y1] formulas=[y,1+y^2] hessianImplementation=class=SymbolicHessian name=Unnamed evaluation=class=SymbolicEvaluation name=Unnamed inputVariablesNames=[y] outputVariablesNames=[y0,y1] formulas=[y,1+y^2]

# %%
# Get a sample
XDist.getSample(5)
# Out:
# class=Sample name=ConditionalDistribution implementation=class=SampleImplementation name=ConditionalDistribution size=5 dimension=1 description=[X|Theta=f(y)] data=[[0.972811],[-0.655941],[1.05078],[1.27726],[-0.101663]]

# %%
# draw PDF
XDist.drawPDF()
# Out:
# class=Graph name=X|Theta=f(y) PDF implementation=class=GraphImplementation name=X|Theta=f(y) PDF title=X|Theta=f(y) PDF xTitle=X|Theta=f(y) yTitle=PDF axes=ON grid=ON legendposition=topright legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Curve name=Unnamed derived from class=DrawableImplementation name=Unnamed legend=X|Theta=f(y) PDF data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=129 dimension=2 data=[[-1.37143,0],[-1.33999,0],[-1.30854,0],[-1.2771,0],[-1.24566,0],[-1.21421,0],[-1.18277,0],[-1.15133,0],[-1.11988,0],[-1.08844,0],[-1.057,0],[-1.02555,0],[-0.99411,0.00107117],[-0.962666,0.00626513],[-0.931223,0.0117036],[-0.89978,0.0179591],[-0.868337,0.0233363],[-0.836894,0.0295175],[-0.80545,0.0365506],[-0.774007,0.0428271],[-0.742564,0.0497151],[-0.711121,0.0553031],[-0.679677,0.0633458],[-0.648234,0.0698438],[-0.616791,0.079163],[-0.585348,0.0866685],[-0.553905,0.0946385],[-0.522461,0.103094],[-0.491018,0.112056],[-0.459575,0.121548],[-0.428132,0.131591],[-0.396689,0.142208],[-0.365245,0.149617],[-0.333802,0.161242],[-0.302359,0.1735],[-0.270916,0.186411],[-0.239472,0.195391],[-0.208029,0.209431],[-0.176586,0.224168],[-0.145143,0.234384],[-0.1137,0.250301],[-0.0822564,0.261308],[-0.0508132,0.27841],[-0.01937,0.2902],[0.0120732,0.308458],[0.0435165,0.327382],[0.0749597,0.340352],[0.106403,0.360307],[0.137846,0.373923],[0.169289,0.394772],[0.200733,0.416073],[0.232176,0.430486],[0.263619,0.452364],[0.295062,0.467083],[0.326505,0.48929],[0.357949,0.511564],[0.389392,0.533801],[0.420835,0.548556],[0.452278,0.570506],[0.483721,0.592152],[0.515165,0.6134],[0.546608,0.634164],[0.578051,0.654365],[0.609494,0.680307],[0.640938,0.698945],[0.672381,0.716831],[0.703824,0.739445],[0.735267,0.755449],[0.76671,0.775481],[0.798154,0.794002],[0.829597,0.815032],[0.86104,0.833729],[0.892483,0.850146],[0.923926,0.866924],[0.95537,0.884531],[0.986813,0.900289],[1.01826,0.772588],[1.0497,0.688314],[1.08114,0.617547],[1.11259,0.571429],[1.14403,0.52638],[1.17547,0.493409],[1.20692,0.450687],[1.23836,0.419672],[1.2698,0.389614],[1.30125,0.370138],[1.33269,0.341807],[1.36413,0.314579],[1.39557,0.288493],[1.42702,0.271751],[1.45846,0.247627],[1.4899,0.232211],[1.52135,0.210092],[1.55279,0.196017],[1.58423,0.17591],[1.61568,0.157],[1.64712,0.145054],[1.67856,0.128112],[1.71001,0.112326],[1.74145,0.0976773],[1.77289,0.0841423],[1.80434,0.0716983],[1.83578,0.0603222],[1.86722,0.046776],[1.89867,0.0350361],[1.93011,0.0250546],[1.96155,0.0132877],[1.993,0.00262884],[2.02444,0],[2.05588,0],[2.08733,0],[2.11877,0],[2.15021,0],[2.18166,0],[2.2131,0],[2.24454,0],[2.27598,0],[2.30743,0],[2.33887,0],[2.37031,0],[2.40176,0],[2.4332,0],[2.46464,0],[2.49609,0],[2.52753,0],[2.55897,0],[2.59042,0],[2.62186,0],[2.6533,0]] color=red fillStyle=solid lineStyle=solid pointStyle=none lineWidth=2]
