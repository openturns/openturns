# %% [markdown]
# # Create a composite design of experiments

# %% [markdown]
# In this basic example we are going to create a deterministic design experiment of type composite.

# %%
from __future__ import print_function
import openturns as ot

# %%
# Define position, scale
center = [0.5, 1.5]
levels = [4, 8, 16]

# %%
# Create the design
myPlane = ot.Composite(center, levels)
sample = myPlane.generate()

# %%
# Plot the design
graph = ot.Graph("Composite design", "x1", "x2", True, "")
cloud = ot.Cloud(sample, "blue", "fsquare", "")
graph.add(cloud)
graph
# Out:
# class=Graph name=Composite design implementation=class=GraphImplementation name=Composite design title=Composite design xTitle=x1 yTitle=x2 axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Composite plane implementation=class=SampleImplementation name=Composite plane size=25 dimension=2 data=[[0.5,1.5],[-3.5,-2.5],[4.5,-2.5],[-3.5,5.5],[4.5,5.5],[-7.5,-6.5],[8.5,-6.5],[-7.5,9.5],[8.5,9.5],[-15.5,-14.5],[16.5,-14.5],[-15.5,17.5],[16.5,17.5],[4.5,1.5],[-3.5,1.5],[0.5,5.5],[0.5,-2.5],[8.5,1.5],[-7.5,1.5],[0.5,9.5],[0.5,-6.5],[16.5,1.5],[-15.5,1.5],[0.5,17.5],[0.5,-14.5]] color=blue fillStyle=solid lineStyle=solid pointStyle=fsquare lineWidth=1]
