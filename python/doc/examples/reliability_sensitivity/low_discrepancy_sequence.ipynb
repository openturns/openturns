# %% [markdown]
# # Generate low discrepancy sequences

# %% [markdown]
# In this examples we are going to expose the available low discrepancy sequences in order to approximate some integrals.
#
# The following low-discrepancy sequences are available:
#
# - Sobol
# - Faure
# - Halton
# - reverse Halton
# - Haselgrove
#
# To illustrate these sequences we generate their first 1024 points and compare with the sequence obtained from the pseudo random generator (Merse Twister) as the latter has a higher discrepancy.

# %%
from __future__ import print_function
import openturns as ot
import math as m

# %%
# 1. Sobol sequence
dimension = 2
size = 1024
sequence = ot.SobolSequence(2)
sample = sequence.generate(size)
graph = ot.Graph("Sobol", "", "", True, "")
cloud = ot.Cloud(sample)
graph.add(cloud)
graph
# Out:
# class=Graph name=Sobol implementation=class=GraphImplementation name=Sobol title=Sobol xTitle= yTitle= axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1024 dimension=2 data=[[0.5,0.5],[0.75,0.25],[0.25,0.75],...,[0.500977,0.25293],[0.000976562,0.75293],[0.00146484,0.376465]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]

# %%
# 2. Halton sequence
dimension = 2
sequence = ot.HaltonSequence(2)
sample = sequence.generate(size)
graph = ot.Graph("Halton", "", "", True, "")
cloud = ot.Cloud(sample)
graph.add(cloud)
graph
# Out:
# class=Graph name=Halton implementation=class=GraphImplementation name=Halton title=Halton xTitle= yTitle= axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1024 dimension=2 data=[[0.5,0.333333],[0.25,0.666667],[0.75,0.111111],...,[0.499023,0.866027],[0.999023,0.310471],[0.000488281,0.643804]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]

# %%
# 3. Reverse Halton sequence
sequence = ot.ReverseHaltonSequence(dimension)
sample = sequence.generate(size)
print('discrepancy=', ot.LowDiscrepancySequenceImplementation.ComputeStarDiscrepancy(sample))
graph = ot.Graph("Reverse Halton", "", "", True, "")
cloud = ot.Cloud(sample)
graph.add(cloud)
graph
# Out:
# discrepancy= 0.0035074981424325635
# class=Graph name=Reverse Halton implementation=class=GraphImplementation name=Reverse Halton title=Reverse Halton xTitle= yTitle= axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1024 dimension=2 data=[[0.5,0.666667],[0.25,0.333333],[0.75,0.222222],...,[0.499023,0.620942],[0.999023,0.176497],[0.000488281,0.843164]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]

# %%
# 4. Haselgrove sequence
sequence = ot.HaselgroveSequence(dimension)
sample = sequence.generate(size)
graph = ot.Graph("Haselgrove", "", "", True, "")
cloud = ot.Cloud(sample)
graph.add(cloud)
graph
# Out:
# class=Graph name=Haselgrove implementation=class=GraphImplementation name=Haselgrove title=Haselgrove xTitle= yTitle= axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=Unnamed implementation=class=SampleImplementation name=Unnamed size=1024 dimension=2 data=[[0.414214,0.732051],[0.828427,0.464102],[0.242641,0.196152],...,[0.326261,0.155925],[0.740474,0.887976],[0.154688,0.620027]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]

# %%
# Compare with uniform random sequence
distribution = ot.ComposedDistribution([ot.Uniform(0.0, 1.0)]*2)
sample = distribution.getSample(size)
print('discrepancy=', ot.LowDiscrepancySequenceImplementation.ComputeStarDiscrepancy(sample))
graph = ot.Graph("Mersenne Twister", "", "", True, "")
cloud = ot.Cloud(sample)
graph.add(cloud)
graph
# Out:
# discrepancy= 0.03685516518292309
# class=Graph name=Mersenne Twister implementation=class=GraphImplementation name=Mersenne Twister title=Mersenne Twister xTitle= yTitle= axes=ON grid=ON legendposition= legendFontSize=1 drawables=[class=Drawable name=Unnamed implementation=class=Cloud name=Unnamed derived from class=DrawableImplementation name=Unnamed legend= data=class=Sample name=ComposedDistribution implementation=class=SampleImplementation name=ComposedDistribution size=1024 dimension=2 description=[X0,X1] data=[[0.629877,0.743423],[0.882805,0.775774],[0.135276,0.482668],...,[0.462643,0.384798],[0.384155,0.733685],[0.284279,0.116958]] color=blue fillStyle=solid lineStyle=solid pointStyle=plus lineWidth=1]
